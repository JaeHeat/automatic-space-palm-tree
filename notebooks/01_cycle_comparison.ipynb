# %% [markdown]
# # BTC cycle comparison
#
# Overlay each post-halving cycle on a common axis (rebased to 100 at the halving, log scale) and compare drawdown profiles. Useful for asking *"where are we vs the last bear/bull?"*
#
# > Data: BTC = FRED `CBBTCUSD` (history starts 2014-12, so the 2016/2020/2024 halvings are covered).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent / 'src'))
# %matplotlib inline
import matplotlib; matplotlib.use('module://matplotlib_inline.backend_inline')
from cryptomacro import analysis, plotting

# %% [markdown]
# ## Run

# %%
res = analysis.analyze_cycles()
print(res.summary)

# %% [markdown]
# Per-cycle stats:

# %%
res.stats

# %% [markdown]
# ## Chart

# %%
fig = plotting.plot_cycle_comparison(res); fig
