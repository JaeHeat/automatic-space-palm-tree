# %% [markdown]
# # BTC vs Nasdaq-100 (NQ)
#
# Rolling correlation of daily returns plus a rolling and full-sample **OLS beta** of BTC on the Nasdaq-100 — i.e. how much "leveraged tech risk" BTC is carrying, and how that has drifted over time.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent / 'src'))
# %matplotlib inline
import matplotlib; matplotlib.use('module://matplotlib_inline.backend_inline')
from cryptomacro import analysis, plotting

# %% [markdown]
# ## Run

# %%
res = analysis.analyze_nq()
print(res.summary)

# %% [markdown]
# Full-sample OLS (alpha/beta/R²/t-stats):

# %%
res.full_ols

# %% [markdown]
# ## Chart

# %%
fig = plotting.plot_nq_correlation(res); fig
