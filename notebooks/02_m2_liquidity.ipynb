# %% [markdown]
# # BTC vs Global M2 liquidity
#
# Global M2 = US + Euro area + China + Japan, each converted to USD. We correlate **YoY growth rates** (not raw levels) to avoid spurious trend-on-trend correlation, estimate the **lead-lag** (does liquidity lead BTC?), and split correlation by **bull/bear regime**.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent / 'src'))
# %matplotlib inline
import matplotlib; matplotlib.use('module://matplotlib_inline.backend_inline')
from cryptomacro import analysis, plotting

# %% [markdown]
# ## Run

# %%
res = analysis.analyze_m2_liquidity()
print(res.summary)

# %% [markdown]
# Return correlation, bull vs bear:

# %%
res.regime_corr

# %% [markdown]
# Lead-lag table (months M2 leads BTC):

# %%
res.lead_lag.set_index('lag')

# %% [markdown]
# ## Chart

# %%
fig = plotting.plot_m2_liquidity(res); fig
