# %% [markdown]
# # BTC vs the business cycle
#
# Condition BTC's monthly returns on US macro regimes: yield-curve inversion, industrial-production momentum, and NBER recessions. Shows average return, volatility and hit-rate in each regime.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent / 'src'))
# %matplotlib inline
import matplotlib; matplotlib.use('module://matplotlib_inline.backend_inline')
from cryptomacro import analysis, plotting

# %% [markdown]
# ## Run

# %%
res = analysis.analyze_business_cycle()
print(res.summary)

# %% [markdown]
# By yield-curve regime:

# %%
res.by_yield_curve

# %% [markdown]
# By industrial-production momentum:

# %%
res.by_growth

# %% [markdown]
# ## Chart

# %%
fig = plotting.plot_business_cycle(res); fig
